# %%
import numpy as np
import os
import sys
from iautils import cascade
import pandas as pd
from datetime import datetime
from astropy.coordinates import SkyCoord
# Out:
# /opt/pysetup/.venv/lib/python3.11/site-packages/chime_frb_api/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution as _get_distribution

# %%
sys.path.append("/arc/home/mseth/.local/lib/python3.11/site-packages")
import memory_profiler
# %load_ext memory_profiler

# %%
source_name = "CYG_A"
coords = SkyCoord.from_name(source_name)
source_ra = coords.ra.deg
source_dec = coords.dec.deg

# %%
path = "/arc/projects/chime_frb/mseth/tau_A_data"

filepaths = []
for (root, dirs, file) in os.walk(path):
    for f in file: 
        filepaths.append(os.path.join(root, f))

# %%
# %%memit
# dms = []
# max_tidxs = []
# max_timestamps = []
# spectra = []
# beam_ids = []
# has_at_peak = []
# y_at_peak = []
# good_filepaths = []
#
# for filepath in filepaths:
#     try:
#         cascade_obj = cascade.load_cascade_from_file(filepath)
#         cascade_obj.dm=57.70
#         dm = cascade_obj.best_snr_dm
#
#         if 55 <= dm <= 57:
#             ts = np.nansum(cascade_obj.beams[cascade_obj._max_beam_idx].intensity, axis=0)
#             max_tidx = np.argmax(ts)
#             max_timestamp = cascade_obj.event_time + pd.Timedelta(seconds = max_tidx / 1000)
#             spectrum_at_peak = cascade_obj.beams[cascade_obj._max_beam_idx].intensity[:, max_tidx]
#             beam_id = cascade_obj.beams[cascade_obj.__max_beam_id].beam_no
#
#             x, y = utils.get_position_from_equatorial(source_ra, source_dec, max_timestamp)
#
#             dms.append(dm)
#             max_tidxs.append(max_tidx)
#             max_timestamps.append(max_timestamp)
#             beam_ids.append(beam_id)
#             has_at_peak.append(x)
#             y_at_peak.append(y)
#             good_filepaths.append(filepath)
#
#             del cascade_obj
#         else:
#             del cascade_obj
#             continue
#
#     except Exception as e:
#         print(e)
#         del cascade_obj
#         continue
# Out:
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# 'Cascade' object has no attribute '__max_beam_id'
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
#
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# De-dispersing to 57.7 pc cm-3..
# Using 400.1953125 MHz as reference..
# Padding shifted channels using median value..
# Process MemTimer-3:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/arc/home/mseth/.local/lib/python3.11/site-packages/memory_profiler.py", line 262, in run
#     stop = self.pipe.poll(self.interval)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/multiprocessing/connection.py", line 440, in _poll
#     r = wait([self], timeout)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/multiprocessing/connection.py", line 948, in wait
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_44/902984263.py", line 1, in <module>
#     get_ipython().run_cell_magic('memit', '', 'dms = []\nmax_tidxs = []\nmax_timestamps = []\nspectra = []\nbeam_ids = []\nhas_at_peak = []\ny_at_peak = []\ngood_filepaths = []\n\nfor filepath in filepaths:\n    try:\n        cascade_obj = cascade.load_cascade_from_file(filepath)\n        cascade_obj.dm=57.70 \n        dm = cascade_obj.best_snr_dm\n\n        if 55 <= dm <= 57:\n            ts = np.nansum(cascade_obj.beams[cascade_obj._max_beam_idx].intensity, axis=0)\n            max_tidx = np.argmax(ts)\n            max_timestamp = cascade_obj.event_time + pd.Timedelta(seconds = max_tidx / 1000)\n            spectrum_at_peak = cascade_obj.beams[cascade_obj._max_beam_idx].intensity[:, max_tidx]\n            beam_id = cascade_obj.beams[cascade_obj.__max_beam_id].beam_no\n\n            x, y = utils.get_position_from_equatorial(source_ra, source_dec, max_timestamp)\n\n            dms.append(dm)\n            max_tidxs.append(max_tidx)\n            max_timestamps.append(max_timestamp)\n            beam_ids.append(beam_id)\n            has_at_peak.append(x)\n            y_at_peak.append(y)\n            good_filepaths.append(filepath)\n\n            del cascade_obj\n        else:\n            del cascade_obj\n            continue\n\n    except Exception as e:\n        print(e)\n        del cascade_obj\n        continue\n')
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2565, in run_cell_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/arc/home/mseth/.local/lib/python3.11/site-packages/memory_profiler.py", line 1113, in memit
#     tmp = memory_usage((_func_exec, (stmt, self.shell.user_ns)),
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/arc/home/mseth/.local/lib/python3.11/site-packages/memory_profiler.py", line 379, in memory_usage
#     returned = f(*args, **kw)
#                ^^^^^^^^^^^^^^
#   File "/arc/home/mseth/.local/lib/python3.11/site-packages/memory_profiler.py", line 889, in _func_exec
#     exec(stmt, ns)
#   File "<string>", line 13, in <module>
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/iautils/cascade.py", line 350, in dm
#     beam.dedisperse(dm=value)
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/iautils/spectra.py", line 774, in dedisperse
#     self.shift_channels(
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/iautils/spectra.py", line None, in shift_channels
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2194, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1182, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1053, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 861, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 773, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/pysetup/.venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 536, in format_record
#     assert isinstance(frame_info.lineno, int)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError

# %%
np.savez("Data.npz", DM=dms, MAX_TIDX=max_tidxs, MAX_TIMESTAMP=max_timestamps, BEAM_ID=beam_ids, 
         HA=has_at_peak, Y=y_at_peak)

# %%
spectra_at_peak = np.vstack(spectra)
    np.savez("Spectra.npz", SPECTRUM=spectra_at_peak)
