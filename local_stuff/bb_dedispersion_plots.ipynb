# %%
import iautils
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# '/users/mseth'

# %% [markdown]
# ### DM histogram w/ all cascade files###

# %%
path = "/users/mseth/Documents/cascades/"

cascade_files_56 = []
cascade_files_57 = []

for (root, dirs, file) in os.walk(path):
    for f in file: 
        cascade_files_56.append(os.path.join(root, f))
        cascade_files_57.append(os.path.join(root, f))

# %%
from iautils import cascade

dms_56 = []
for cascade_file in cascade_files_56:
        # Load the cascade file
    try:
        cascade_obj = cascade.load_cascade_from_file(cascade_file)
    except Exception as e:
        print(e)
        continue
    dm = cascade_obj.best_snr_dm
    dms_56.append(dm)


dms_57 = []
for cascade_file in cascade_files_56:
        # Load the cascade file
    try:
        cascade_obj = cascade.load_cascade_from_file(cascade_file)
        cascade_obj.dm=57.70 ## De-dispersing at 57.70

    except Exception as e:
        print(e)
        continue
    dm = cascade_obj.best_snr_dm
    dms_57.append(dm)
# Out:
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# ...

# %%
# %matplotlib ipympl

# %% [markdown]
# ### DM histogram with just crab files ###

# %%
dm_filter_56 = []

dms_56 = np.array(dms_56)
dm_filter_56 = np.where((dms_56 >= 55) & (dms_56 <= 57))[0]

dm_filter_57 = []

dms_57 = np.array(dms_57)
dm_filter_57 = np.where((dms_57 >= 55) & (dms_57 <= 57))[0]

# %%
crab_dms_56 = [dms_56[i] for i in dm_filter_56]
crab_dms_57 = [dms_57[i] for i in dm_filter_57]

# %%
crab_cascades_56 = [cascade_files_56[i] for i in dm_filter_56]
crab_cascades_57 = [cascade_files_57[i] for i in dm_filter_57]

crab_files_56 = []
crab_files_57 = []


for crab_cascade in crab_cascades_56:
    try:
        cascade_obj = cascade.load_cascade_from_file(crab_cascade)
    except Exception as e:
        print(e)
        continue
    crab_files_56.append(cascade_obj)

for crab_cascade in crab_cascades_57:
    try:
        cascade_obj = cascade.load_cascade_from_file(crab_cascade)
    except Exception as e:
        print(e)
        continue
    crab_files_57.append(cascade_obj)
# Out:
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# Preprocessing...
# using L1 weights
# ...

# %% [markdown]
# ### Effective Width ###

# %%
W_eff_56 = []

for crab_file in crab_files_56:
    max_beam = crab_file._max_beam_idx
    time_srs = np.nansum(crab_file.beams[max_beam].intensity,axis=0)
    
    max_int = np.max(time_srs)
    max_idx = np.argmax(time_srs)

    window = np.arange(max_idx - 10, max_idx + 10, 1)

    masked_ts = [time_srs[i] for i in window]
    
    fluence = np.nansum(masked_ts, axis=0)
    w_eff = fluence/max_int
    W_eff_56.append(w_eff)


W_eff_57 = []

for crab_file in crab_files_57:
    max_beam = crab_file._max_beam_idx
    time_srs = np.nansum(crab_file.beams[max_beam].intensity,axis=0)
    
    max_int = np.max(time_srs)
    max_idx = np.argmax(time_srs)

    window = np.arange(max_idx - 10, max_idx + 10, 1)

    masked_ts = [time_srs[i] for i in window]
    
    fluence = np.nansum(masked_ts, axis=0)
    w_eff = fluence/max_int
    W_eff_57.append(w_eff)

# %%
palette = sns.color_palette("deep")
sns.set_palette("deep")

# %%
sns.set_theme()

# %%
print(W_eff_57)
# Out:
# [1.0776804157333701, 1.5624200952038738, 1.2903887468451312, 1.8557711365756977, 1.5828106376562607, 6.488330655821525, 1.5312171068590184, 4.112451415346851, 7.83792138460556, 1.4463697965593842, 2.3106645997134194, 1.8573060700837427, 11.284717447141686, 1.4491061609760927, 10.022761966661758, 4.119584536641535, 4.069416791938299, 1.8523990658935718, 9.368765219245013, 4.606267362653713, 1.4320901049209855, 6.996563153992624, 1.9649248290654804, 6.444509338042011, 0.9125986476664689, 7.407501621416356, 3.6220412261084234, 1.9765614387872863, 4.937810469106512, 6.153410562096891, 4.618946122936395, 3.1581665239951913, 4.56647931964513, 3.3620256321326036, 1.0472330800144536, 3.572669876993627, 1.2909698091857014, 9.890340744743138, 9.380983609872503, 7.684256819686332, 6.297479832369683, 1.5098454233407392, 2.1347961842216816, 2.6935663767693963, 1.5266735119556458, 1.087819163202262, 1.0123240190689087, 0.8739243584055681]

# %%
fig, ax = plt.subplot_mosaic(
    '''
    AABBB
    ''',
    figsize = (12, 6),
    constrained_layout = True)

#Effective width vs. DM scatter plot
ax['A'].scatter(W_eff_one, crab_dms_56)
ax['A'].set_ylabel('DM')
ax['A'].set_xlabel('Effective width after initial dedispersion')

palette_two = sns.color_palette('pastel')
#Histogram showing improvement in effective width after dedispersion
ax['B'].hist(W_eff_one, 
        bins = 'auto',
        color = palette[6],
        label = 'Initial dedispersion',
        alpha = 0.6,
        histtype = 'stepfilled')
ax['B'].hist(W_eff_57, 
        label = 'After dedispersing at 57.7 pc cm^-3',
        bins='auto',
        color = palette[0],
        lw = 3,
        histtype = 'step')

ax['B'].legend()

ax['B'].set_xlabel("Pulse effective width")
ax['B'].set_ylabel("No. of pulses");
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
W_eff_one = np.array([1.1357386091648463, 1.6012385934709996, 1.593161520367418, 1.4652903193261766, 1.6515140837087094, 7.378353789441842, 1.3590421781829667, 4.895979260956686, 7.8078249807967275, 1.6481780638696009, 2.6497192611948064, 1.8395112458801262, 15.550594824227192, 1.5908931934594295, 10.619585409642253, 2.9103420491790293, 3.013423383087025, 2.3296392098695997, 12.329676035775059, 5.115562286382783, 1.6396046016983152, 8.862231959414414, 1.9406631400391225, 6.738550297092531, 0.6583453829231645, 7.75862771770491, 3.5027987975899597, 0.10651813310030896, 4.912751779601929, 6.650380475398317, 4.004278278294539, 2.753105637688264, 4.117330664884317, 2.4022679928575013, 0.8929367846130137, 3.6960246662763, 1.8516383717270943, 12.155939947242459, 10.229422982657631, 7.641521475247553, 6.601451420495707, 1.7076695704156317, 2.428870231986791, 3.4253667539652373, 1.3608388330618792, 1.223503178759386, 1.1414023028141362, 0.9377547492995646])

# %%
fig, ax = plt.subplots(
    figsize = (8, 8),
    constrained_layout = True)

ax.hist(W_eff_one, 
        bins = 'auto',
        histtype = 'stepfilled')

ax.set_xlabel("Pulse effective width")
ax.set_ylabel("No. of pulses");
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
